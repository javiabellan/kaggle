# %%
import pandas as pd

# %%
# !ls
# Out:
# ColumnTransformer.joblib  results_NN1.csv  tf-optuna-train.py  utils
# MoA_UMAP_continuosVars	  results_NN2.csv  Tmp.ipynb

# %%
nn1 = pd.read_csv("results_NN1.csv")
nn1 = nn1.sort_values(by=['score'])
nn1
# Out:
#      Unnamed: 0 activation  batch_size  dropout  epochs  hidden_dim  \
# 110         110        elu       200.0     0.50    22.0      1634.0
# 113         113        elu       200.0     0.50    21.0      1662.0
# 121         121        elu       200.0     0.50    22.0      1594.0
# 108         108        elu       200.0     0.50    21.0      1660.0
# 124         124        elu       200.0     0.50    24.0      1442.0
# ..          ...        ...         ...      ...     ...         ...
# 84           84        elu        96.0     0.10    24.0      1826.0
# 3             3       relu        96.0     0.05    44.0       572.0
# 1             1        elu       128.0     0.30    22.0      1543.0
# 9             9        elu        96.0     0.40     6.0      1548.0
# 19           19        elu       128.0     0.15     4.0      1942.0
#
#      hidden_layers  lookahead    lr_max  lr_sched     score        time
# 110            2.0        0.0  0.064375  OneCycle  0.014877   20.018919
# ...

# %%
nn2 = pd.read_csv("results_NN2.csv")
nn2 = nn2.sort_values(by=['score'])
nn2
# Out:
#      Unnamed: 0 activation  batch_size  cell_dim  dropout  epochs  gene_dim  \
# 398         398        elu       160.0      50.0     0.65    15.0     240.0
# 359         359        elu       160.0      50.0     0.65    15.0     230.0
# 353         353        elu       160.0      50.0     0.65    15.0     220.0
# 388         388        elu       160.0      50.0     0.60    13.0     250.0
# 366         366        elu       160.0      50.0     0.65    14.0     230.0
# ..          ...        ...         ...       ...      ...     ...       ...
# 2             2       relu        64.0      10.0     0.20    42.0     150.0
# 55           55        elu        96.0      20.0     0.30    28.0     110.0
# 8             8        elu        96.0      45.0     0.20    33.0      70.0
# 0             0       relu       160.0      40.0     0.20    43.0     150.0
# 23           23       relu        96.0      15.0     0.15    37.0      40.0
#
# ...
